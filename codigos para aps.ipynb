# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#instruciones q le damos  a python para que lea lo que tengo en el archivo .env de mis "secretos"
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# False

# %%
mi_key = os.getenv("api_key")

# %%
pip install pandas
# Out:
# ...
#
# ...
