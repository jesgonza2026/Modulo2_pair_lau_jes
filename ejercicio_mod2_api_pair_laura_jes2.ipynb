# %%
import requests
import pandas as pd

# %%
0c963d83-cae6-4b43-9694-c1fb04200336              #apikey

# %%
url = "https://api.balldontlie.io/v1/players0c963d83-cae6-4b43-9694-c1fb04200336"

# %%
print(url)
# Out:
# https://api.balldontlie.io/v1/players0c963d83-cae6-4b43-9694-c1fb04200336

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 401

# %%
response.reason
# Out:
# 'Unauthorized'

# %%
"https://api.balldontlie.io/v1/players" \
  -H "Authorization: YOUR_API_KEY"

# %%
url = "https://api.balldontlie.io/v1/players"
cabecera = {"Authorization": "0c963d83-cae6-4b43-9694-c1fb04200336"}

# %%
response = requests.get(url,headers=cabecera)

# %%
response.status_code
# Out:
# 200

# %%
len(response.json())
# Out:
# 2

# %%
print(response.json().keys)
# Out:
# <built-in method keys of dict object at 0x0000020D63508A40>

# %%
print(response.json(keys))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 print(response.json(keys))
#
# NameError: name 'keys' is not defined

# %% [markdown]
# El nombre, apellido y equipo

# %%
diccionario= ["data"][0]

# %%
print(diccionario)
# Out:
# data

# %%
for jugador in diccionario[1]:
    nombre = jugador[1]
    apellido = jugador[1]
    equipo = jugador['team']['full_name']
    
    print(nombre, apellido, "-", equipo)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 2
#       1 for jugador in diccionario[1]:
# ----> 2     nombre = jugador[1]
#       3     apellido = jugador[1]
#       4     equipo = jugador['team']['full_name']
#
# IndexError: string index out of range
